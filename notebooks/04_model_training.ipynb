# %% [markdown]
# # 04. Model Training & Tuning
# This notebook runs the algorithm comparison, trains models, performs GridSearchCV hyperparameter tuning, and evaluates results.

# %%
from src.train import train_and_compare, tune_and_save_best

# Run training and tuning
best_name, best_model = train_and_compare()
tune_and_save_best(best_name, best_model)
