# %% [markdown]
# # 01. Data Cleaning
# This notebook loads the raw UCI Cleveland Heart Disease dataset, handles missing values, identifies duplicates, and performs target label preprocessing.

# %%
import pandas as pd
import numpy as np
import os
from src import config
from src.preprocessing import load_raw_data, clean_data, detect_outliers_iqr

# Load raw data
df = load_raw_data(config.RAW_DATA_PATH)
df.head()

# %%
# Check missing values
print("Missing values check:")
print(df.replace('?', np.nan).isnull().sum())

# %%
# Clean data
df_cleaned = clean_data(df)
df_cleaned.head()
